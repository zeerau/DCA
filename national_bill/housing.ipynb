# %%
import pandas as pd

# %%
df0 = pd.read_csv(r'C:\Users\DELL\Documents\DCA\national_bill\table_19.csv')
df1 = pd.read_csv(r'C:\Users\DELL\Documents\DCA\national_bill\table_20.csv')
df2 = pd.read_csv(r'C:\Users\DELL\Documents\DCA\national_bill\table_21.csv')
df3 = pd.read_csv(r'C:\Users\DELL\Documents\DCA\national_bill\table_22.csv')

# %%
df0
# Out:
#    Unnamed: 0   Unnamed: 1  OFFICE OF THE CHIEF  Unnamed: 2   Unnamed: 3  \
# 0         5.0  111001005.0                  NaN         0.0  212,489,223
# 1         NaN          NaN  SECURITY OFFICER TO         NaN          NaN
# 2         NaN          NaN        THE PRESIDENT         NaN          NaN
# 3         NaN          NaN  STATE HOUSE MEDICAL         NaN          NaN
# 4         6.0  111001006.0                  NaN         0.0  632,987,856
#
#     Unnamed: 4  Unnamed: 5  Unnamed: 6     Unnamed: 7
# 0  226,786,946         0.0         0.0    439,276,169
# 1          NaN         NaN         NaN            NaN
# 2          NaN         NaN         NaN            NaN
# 3          NaN         NaN         NaN            NaN
# 4  494,024,805         0.0         0.0  1,127,012,661

# %%
df2
# Out:
#    0111001001                                STATE HOUSE - HQTRS  \
# 0        CODE                                          LINE ITEM
# 1           2                                        EXPENDITURE
# 2          21                                     PERSONNEL COST
# 3        2101                                             SALARY
# 4      210101                                 SALARIES AND WAGES
# 5    21010101                                             SALARY
# 6        2102                 ALLOWANCES AND SOCIAL CONTRIBUTION
# 7      210201                                         ALLOWANCES
# 8    21020111                                 REGULAR ALLOWANCES
# 9      210202                               SOCIAL CONTRIBUTIONS
# 10   21020201                                               NHIS
# 11   21020202     CONTRIBUTORY PENSION - EMPLOYER'S CONTRIBUTION
# 12         22                              OTHER RECURRENT COSTS
# ...

# %%
table= pd.concat([df2,df3],ignore_index=True)
table
# Out:
#    0111001001                               STATE HOUSE - HQTRS  \
# 0        CODE                                         LINE ITEM
# 1           2                                       EXPENDITURE
# 2          21                                    PERSONNEL COST
# 3        2101                                            SALARY
# 4      210101                                SALARIES AND WAGES
# ..        ...                                               ...
# 79   23030101  REHABILITATION / REPAIRS OF RESIDENTIAL BUILDING
# 80   23030121      REHABILITATION / REPAIRS OF OFFICE BUILDINGS
# 81       2304                   PRESERVATION OF THE ENVIRONMENT
# 82     230401         PRESERVATION OF THE ENVIRONMENT - GENERAL
# 83   23040103                             WILDLIFE CONSERVATION
#
#         Unnamed: 0
# 0           AMOUNT
# 1   47,111,611,995
# 2    3,497,320,200
# 3    2,345,306,769
# 4    2,345,306,769
# ..             ...
# 79     654,418,467
# 80  25,362,462,362
# ...

# %%
table.columns = table.iloc[0]
table=table[1:]
table
# Out:
# 0       CODE                                         LINE ITEM          AMOUNT
# 1          2                                       EXPENDITURE  47,111,611,995
# 2         21                                    PERSONNEL COST   3,497,320,200
# 3       2101                                            SALARY   2,345,306,769
# 4     210101                                SALARIES AND WAGES   2,345,306,769
# 5   21010101                                            SALARY   2,345,306,769
# ..       ...                                               ...             ...
# 79  23030101  REHABILITATION / REPAIRS OF RESIDENTIAL BUILDING     654,418,467
# 80  23030121      REHABILITATION / REPAIRS OF OFFICE BUILDINGS  25,362,462,362
# 81      2304                   PRESERVATION OF THE ENVIRONMENT     124,612,890
# 82    230401         PRESERVATION OF THE ENVIRONMENT - GENERAL     124,612,890
# 83  23040103                             WILDLIFE CONSERVATION     124,612,890
#
# [83 rows x 3 columns]
